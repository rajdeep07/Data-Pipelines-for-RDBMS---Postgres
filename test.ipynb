# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 22, 0, 3, 52, 796000), '15', 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 22, 0, 9, 10, 796000), '15', 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 22, 0, 12, 6, 796000), '15', 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 22, 0, 15, 41, 796000), '15', 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 22, 0, 23, 40, 796000), '15', 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('101', 'Jayden', 'Fox', 'M', 'free'),
#  ('15', 'Lily', 'Koch', 'F', 'paid'),
#  ('23', 'Morris', 'Gilmore', 'M', 'free'),
#  ('26', 'Ryan', 'Smith', 'M', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 114.78159),
#  ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 114.78159),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 218.77506),
#  ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233.40363),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.39628)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', None, None),
#  ('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', None, None),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', None, None),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', None, None)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 22, 0, 3, 52, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 22, 0, 9, 10, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 22, 0, 12, 6, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 22, 0, 15, 41, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 22, 0, 23, 40, 796000), 0, 22, 47, 11, 2018, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql SELECT location, count(location) FROM songplays GROUP BY location;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 63 rows affected.
# [('Atlanta-Sandy Springs-Roswell, GA', 459),
#  ('Nashville-Davidson--Murfreesboro--Franklin, TN', 25),
#  ('Richmond, VA', 13),
#  ('Lubbock, TX', 28),
#  ('Birmingham-Hoover, AL', 223),
#  ('San Francisco-Oakland-Hayward, CA', 691),
#  ('Winston-Salem, NC', 213),
#  ('Eureka-Arcata-Fortuna, CA', 16),
#  ('Chicago-Naperville-Elgin, IL-IN-WI', 508),
#  ('Plymouth, IN', 10),
#  ('Marinette, WI-MI', 169),
#  ('Youngstown-Warren-Boardman, OH-PA', 8),
#  ('Phoenix-Mesa-Scottsdale, AZ', 27),
#  ('New Haven-Milford, CT', 49),
#  ('Raleigh, NC', 6),
#  ('Milwaukee-Waukesha-West Allis, WI', 9),
#  ('Portland-Vancouver-Hillsboro, OR-WA', 7),
#  ('Elkhart-Goshen, IN', 2),
#  ('San Diego-Carlsbad, CA', 5),
#  ('Dallas-Fort Worth-Arlington, TX', 21),
#  ('Longview, TX', 17),
#  ('Waterloo-Cedar Falls, IA', 397),
#  ('Seattle-Tacoma-Bellevue, WA', 15),
#  ('Columbia, SC', 25),
#  ('Portland-South Portland, ME', 666),
#  ('Sacramento--Roseville--Arden-Arcade, CA', 270),
#  ('Detroit-Warren-Dearborn, MI', 76),
#  ('Lake Havasu City-Kingman, AZ', 321),
#  ('Janesville-Beloit, WI', 248),
#  ('Tampa-St. Petersburg-Clearwater, FL', 307),
#  ('Salinas, CA', 37),
#  ('Saginaw, MI', 3),
#  ('San Jose-Sunnyvale-Santa Clara, CA', 295),
#  ('Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', 35),
#  ('Indianapolis-Carmel-Anderson, IN', 14),
#  ('Houston-The Woodlands-Sugar Land, TX', 66),
#  ('Ogden-Clearfield, UT', 7),
#  ('Yuba City, CA', 27),
#  ('Klamath Falls, OR', 20),
#  ('La Crosse-Onalaska, WI-MN', 45),
#  ('Santa Rosa, CA', 21),
#  ('Miami-Fort Lauderdale-West Palm Beach, FL', 2),
#  ('Cedar Rapids, IA', 10),
#  ('Parkersburg-Vienna, WV', 5),
#  ('Los Angeles-Long Beach-Anaheim, CA', 6),
#  ('New Orleans-Metairie, LA', 61),
#  ('Red Bluff, CA', 201),
#  ('Pensacola-Ferry Pass-Brent, FL', 3),
#  ('Las Cruces, NM', 6),
#  ('Lansing-East Lansing, MI', 586),
#  ('New York-Newark-Jersey City, NY-NJ-PA', 263),
#  ('Minneapolis-St. Paul-Bloomington, MN-WI', 15),
#  ('St. Louis, MO-IL', 16),
#  ('Eugene, OR', 20),
#  ('Harrisburg-Carlisle, PA', 37),
#  ('Salt Lake City, UT', 4),
#  ('San Antonio-New Braunfels, TX', 52),
#  ('Washington-Arlington-Alexandria, DC-VA-MD-WV', 34),
#  ('Oxnard-Thousand Oaks-Ventura, CA', 7),
#  ('Palestine, TX', 27),
#  ('Myrtle Beach-Conway-North Myrtle Beach, SC-NC', 1),
#  ('Augusta-Richmond County, GA-SC', 140),
#  ('London, KY', 5)]

# %%
# %sql SELECT artists.artist_id, count(song_id) from songplays inner join artists on songplays.artist_id = artists.artist_id group by artists.artist_id;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('AR5KOSW1187FB35FF4', 1)]
